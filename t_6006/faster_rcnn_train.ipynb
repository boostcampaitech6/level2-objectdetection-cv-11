# %%
# 모듈 import
from mmengine.config import Config
from mmengine.runner import Runner

# %%
import mmengine
mmengine.__version__
# Out:
# '0.10.2'

# %%
# config file 들고오기
cfg = Config.fromfile('./configs/faster_rcnn/faster-rcnn_r50_fpn_1x_coco.py')

metainfo = {
    'classes': ('General trash', 'Paper', 'Paper pack', 'Metal', 'Glass', 
                'Plastic', 'Styrofoam', 'Plastic bag', 'Battery', 'Clothing',),
    'palette': [
        (220, 20, 60), (119, 11, 32), (0, 0, 230), (106, 0, 228), (60, 20, 220),
        (0, 80, 100), (0, 0, 70), (50, 0, 192), (250, 170, 30), (255, 0, 0)
    ]
}

data_root='/data/ephemeral/home/dataset/'

cfg.train_dataloader.dataset.metainfo = metainfo
cfg.train_dataloader.dataset.data_root = data_root
cfg.train_dataloader.dataset.ann_file = 'train.json'
cfg.train_dataloader.dataset.data_prefix = dict(img='')
cfg.train_pipeline[2]['scale'] = (512,512) # Resize
cfg.train_dataloader.batch_size = 10

cfg.val_dataloader.dataset.metainfo = metainfo
cfg.val_dataloader.dataset.data_root = data_root
cfg.val_dataloader.dataset.ann_file = 'train.json'
cfg.val_dataloader.dataset.data_prefix = dict(img='')
cfg.val_dataloader.batch_size = 4
cfg.val_evaluator = dict(
    type='CocoMetric',
    ann_file=data_root + 'train.json',
    metric='bbox',
    format_only=False,
    classwise=True,
    )

# cfg.val_cfg = None
# cfg.test_cfg = None
# cfg.val_dataloader = None
# cfg.val_evaluator = None
# cfg.test_dataloader = None
# cfg.test_evaluator = None

# cfg.optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='AdamW', lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0.01)
# )

cfg.work_dir = './work_dirs/faster_rcnn_r50_fpn_1x_trash'

cfg.model.roi_head.bbox_head.num_classes = 10

# vis_backends = [dict(type='LocalVisBackend'),
#                     # dict(type='WandbVisBackend', 
#                     #      init_kwargs={
#                     #          'project': 'test_project',
#                     #          'entity': 'i-will-show-you',
#                     #          'group': 'maskrcnn-r50-fpn-1x-coco'
#                     #          })
#                              ]
# cfg.visualizer = dict(type='DetLocalVisualizer', vis_backends=vis_backends, name='visualizer')

# cfg.train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=1, val_interval=1)

# %%
runner = Runner.from_cfg(cfg)
runner.train()
# Out:
# 01/15 16:05:07 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: False
#     numpy_random_seed: 20053386
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 2.1.2+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
# ...

# %%
Runner.train()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 Runner.train()
#
# TypeError: Runner.train() missing 1 required positional argument: 'self'
